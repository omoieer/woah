# %% [markdown]
# # #This Notebook is for NovelAI with Stable-Diffusion version and 7G animefull-final-latest model used.

# %%
import os
import subprocess
# !apt-get update
#Check if Python 3.9 Already Exists and Symlink Set
not_setup = False

files_to_check = [
    "/opt/conda/bin/python3",
    "/opt/conda/bin/python3.7",
    "/opt/conda/bin/python",
]

target = "/usr/bin/python3.10"

for file_path in files_to_check:
    if os.path.islink(file_path):
        link_target = os.readlink(file_path)
        if link_target == target:
            not_setup = False
        else:
            not_setup = True
    else:
        not_setup = True

if not_setup:
    #Install Python 3.9 Using Apt
    #!sudo apt update -y (optional)
    # !sudo apt install software-properties-common -y
    # !sudo add-apt-repository ppa:deadsnakes/ppa -y

    # !sudo apt install python3.10 -y

    #Find the Location of Python 3.9


    result = subprocess.run(['which', 'python3.10'], stdout=subprocess.PIPE)
    print(result.stdout.decode())

    #Check if Python 3.9 is Working (ensure the location is the same as what was found in the previous cell)
    print("########TEST START########")
    # !/usr/bin/python3.10 --version
    # !echo 'print("Hello, World!")' > test.py
    # !/usr/bin/python3.10 test.py
    print("########TEST END#########")
    print("\n")

    #Delete Python3 files and replace them with a SymLink to Python 3.9
    # !sudo rm /opt/conda/bin/python3
    # !sudo ln -sf /usr/bin/python3.10 /opt/conda/bin/python3
    # !sudo rm /opt/conda/bin/python3.7
    # !sudo ln -sf /usr/bin/python3.10 /opt/conda/bin/python3.7
    # !sudo rm /opt/conda/bin/python
    # !sudo ln -s /usr/bin/python3.10 /opt/conda/bin/python

#Check Python Version
print("Cells following this should be run using:")
# !python --version
# !apt-get remove -y python3-pip
# !curl https://bootstrap.pypa.io/get-pip.py -o get-pip.py
# !python3 get-pip.py --force-reinstall
# !pip install --upgrade pip setuptools

# %%
#Test GPU 测试GPU
# !nvidia-smi

#Download SD-WebUi 下载SD-WebUi
# %cd /kaggle/working/
# !git clone https://github.com/anapnoe/stable-diffusion-webui
# %cd /kaggle/working/stable-diffusion-webui
# !git reset --hard 9931e861dfb128735c4a928a7beb5b5c0af30593
# %cd /kaggle/working/
    
#Make folder for models  新建模型目录
# !mkdir -p /kaggle/working/stable-diffusion-webui/models/Stable-diffusion /kaggle/working/stable-diffusion-webui/models/hypernetworks 
# %cd /kaggle/working/stable-diffusion-webui/models/Stable-diffusion
#xformers
# install xformers

# %%
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt -y install -qq libunwind8-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb

# %%
# !conda uninstall pytorch --yes

# %%
# !pip3 install --pre torch -f https://download.pytorch.org/whl/nightly/cpu/torch_nightly.html
# !pip install -q https://files.pythonhosted.org/packages/db/4b/9a0d2549367896f0de260977c144c6ff7b5079356e31e414d5bce6e4bdd5/xformers-0.0.17-cp310-cp310-manylinux2014_x86_64.whl

# %%
#Select the model you like根据喜好选择模型
#Remove the # signal before the code if you want to run the model, and add the # symbol before the other
#在你想要使用的模型对应的代码前去掉#，其他模型的对应代码前加上#

#Model 1 (default) ： 7g animefull-final-latest
# 二次元和写实风兼有
#!cp -r /kaggle/input/animefulllatestckpt/animefull-latest.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest.ckpt
#!cp -r /kaggle/input/animefulllatestckpt/animefull-latest.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest.vae.pt

#Model 2: 4g animefull-final-pruned
# 二次元风格
#!cp -r /kaggle/input/nai-pruned/animefull-final-pruned.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.ckpt

#Model 3: 7g stable-diffusion-1.5
#写实风
#!cp -r /kaggle/input/stable-diffusion-1-5/v1-5-pruned.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/sd15-pruned.ckpt

#Model 4:7g Anything-v3.0
#Novel AI最新模型
#!cp -r /kaggle/input/anythingv3/Anything-V3.0.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.ckpt
#!cp -r /kaggle/input/anythingv3/Anything-V3.0.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.vae.pt

#Model 5:stable diffusion 1.5 inpainting
#专用于inpaint的模型
#!cp -r /kaggle/input/inpainting/sd-v1-5-inpainting.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt

#Model 5:7g momoko-Anything-v3.0
#看标题像momoko，哪位大哥测试一下效果？
#!git clone https://huggingface.co/xiaolxl/Stable-diffusion-models/blob/main/momoko-e.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko-any3.0.ckpt

#Model 6: NovelAI-Pruned
#!cp -r /kaggle/input/nai-pruned/animefull-final-pruned.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.ckpt
#!cp -r /kaggle/input/nai-pruned/animevae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animevae.pt

#Model 7: Stable Diffusion 2
#!cp -r /kaggle/input/stable-diffusion2-768/768-v-ema.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/768-v-ema.ckpt
#!cp -r /kaggle/input/stable-diffusion2-768/768-v-ema.yaml /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/768-v-ema.yaml

# %%
# !apt -y install -qq aria2
# Models
#momoko
#!aria2c -d /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/ -o momoko-any3.0.ckpt https://huggingface.co/manter/momoko/resolve/main/momoko-any3.0.ckpt
#!aria2c -d /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/ -o momoko-any3.0.vae.pt https://huggingface.co/manter/momoko/resolve/main/momoko-any3.0.vae.pt
#anything v4
# !aria2c -d /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/ -o anything-v4.0.ckpt https://huggingface.co/xyn-ai/anything-v4.0/resolve/main/anything-v4.0.ckpt
# !aria2c -d /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/ -o anything-v4.0.vae.pt https://huggingface.co/xyn-ai/anything-v4.0/resolve/main/anything-v4.0.vae.pt
#!aria2c -d /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/ -o AnyLoRA.safetensors https://huggingface.co/Lykon/AnyLoRA/resolve/main/AnyLoRA_bakedVae_ftmse_fp16_NOTpruned.safetensors
#!aria2c -d /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/ -o momoko-e.ckpt https://huggingface.co/ouo/momoko/resolve/main/momoko-e.ckpt
#!aria2c -d /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/ -o momoko-p.ckpt https://huggingface.co/ouo/momoko/resolve/main/momoko-p.ckpt
# 7G animefull-final-latest (optional)
# !aria2c -d /kaggle/working/stable-diffusion-webui https://cloudflare-ipfs.com/ipfs/bafybeiav3j7npiuewbel3mi32l3sidgkw54kuleosbhxmdvddbnvtfi7yu/config.yaml
#!aria2c https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/animefull-latest.ckpt

# Install embeddings (optional)
#!aria2c https://cloudflare-ipfs.com/ipfs/bafybeie3hdjchxs5tz4n75bos53nhcklslguxchdurc2ynrzcfv2kwyklu/embeddings.tar
#!tar xvf embeddings.tar -C /kaggle/working/stable-diffusion-webui/embeddings && rm -rf embeddings.tar

# Install VAE Weights (optional)
# !aria2c -o animefull-final-pruned.vae.pt https://cloudflare-ipfs.com/ipfs/bafybeiccldswdd3wvg57jhclcq53lvsc6gizasiblwayvhlv6eq4wow7wu/animevae.pt 
# !ln -s animefull-final-pruned.vae.pt animefull-final-latest.vae.pt

# Install hypernetwork （optional)
# !aria2c https://cloudflare-ipfs.com/ipfs/bafybeiduanx2b3mcvxlwr66igcwnpfmk3nc3qgxlpwh6oq6m6pxii3f77e/_modules.tar  
# !tar xvf _modules.tar -C /kaggle/working/stable-diffusion-webui/models/hypernetworks && rm -rf _modules.tar

# %%
#OMORI LoRas
# !aria2c -d /kaggle/working/stable-diffusion-webui/models/Lora -o OMORI.safetensors https://files.catbox.moe/tsf7qb.safetensors
# !aria2c -d /kaggle/working/stable-diffusion-webui/models/Lora -o SUNNY.safetensors https://files.catbox.moe/t53r5k.safetensors
# !aria2c -d /kaggle/working/stable-diffusion-webui/models/Lora -o BASIL.safetensors https://files.catbox.moe/x72odp.safetensors
# !aria2c -d /kaggle/working/stable-diffusion-webui/models/Lora -o MARI.safetensors https://files.catbox.moe/chtfpi.safetensors
# !aria2c -d /kaggle/working/stable-diffusion-webui/models/Lora -o AUBREY.safetensors https://files.catbox.moe/cz855o.safetensors
# !aria2c -d /kaggle/working/stable-diffusion-webui/models/Lora -o KEL.safetensors https://files.catbox.moe/oflf3d.safetensors
# !aria2c -d /kaggle/working/stable-diffusion-webui/models/Lora -o HERO.safetensors https://files.catbox.moe/4o0ipi.safetensors
# !aria2c -d /kaggle/working/stable-diffusion-webui/models/Lora -o SWEETHEART.safetensors https://files.catbox.moe/mlc6sy.safetensors
# !aria2c -d /kaggle/working/stable-diffusion-webui/models/Lora -o OmocatArtStyle.safetensors https://files.catbox.moe/w3b474.safetensors
# !aria2c -d /kaggle/working/stable-diffusion-webui/models/ESRGAN -o RealESRGAN_x4plus_anime_6B.pth https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.2.4/RealESRGAN_x4plus_anime_6B.pth

# %%
#复制训练好的模型copy the pt file to embeddings
#!aria2c -d /kaggle/working/stable-diffusion-webui/embeddings/ -o anime.pt https://www.kaggleusercontent.com/kf/112380629/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0..Gl-THXYN1zz-s2B80RBO1w.ulRuMQ6sVHOdgbSrK-V_wDWE6CrlHRiqr-YPrtEGTKmNwmvVFTWB1iguPbyt3-CfkfH_jVN7cFmn1LFn4FlKC75r9YfQR2O7ehCNomx_DYBsSRc9MVt2Qn31ceHnoi-a1f4TuDdRzcnblaNMIuuoCybK1Yi9FuUmm97ZtNbJque-r8AUKtOQmuDBgsXqLdQwX16oixD7xt4XRLB2Mns3GcxE0y5GrdCLGIJdDI7TxoV9JGa1j-64UTw0FcX0mUEIDtoxUNZJhYsa_BEJQzmNxbANfoeEGuBED8SkKQ2T6wQwWcC3t7Rj6pxOxUbO-W9hazYyaGQ-8CJ-DMEITyVghavpItVIp4Bduld5zriYRSU4We6fbGcfKXx2MT1JQHsYgVm9cboGusgzqtiJ8_SlHw69ciuMBtkwtaWDEi9twQcIfyF1D_-U0MHq-MaedGE6vqqDHsmrU64hr_swXlfTyl6cSz61m5_A8ok_mRChJl9K5tkgpa4REMImH-fgaTVKrcBdeK_GfqN2Fdd0I5Ut7UPEzTATi-rGWbhAcv7A1pY466zscu73AdE0RTkXlq3HRQRk1KeyMCMqUrFvyNi7W2clVuGIBv0muAbOub-7BTUk5uNHE7I8UrqIHYytlLM0UZOb5yFNHJEaHGQuwK7IiZEqUY-JbUXx_bAgrR7mGmRP3otmhXML7CHoWChahYFH.vNp_i_RMYeQtbOKhQHyR0Q/stable-diffusion-webui/embeddings/anime.pt
#!conda install -y gdown
#!gdown --id 1x73fcY9MrnYb09WhrGRUj4TCyptiJKFR -O /kaggle/working/stable-diffusion-webui/models/Stable-diffusion
#!gdown --id 1-153WqjpFTONIvsOmMPBtS51KnLgrGQV -O /kaggle/working/stable-diffusion-webui/models/Stable-diffusion
#训练备用：
#新建用于存放预处理图片的文件夹 create a folder to save the preprocessed data
# !mkdir -p /kaggle/working/preprocessed

# %%
#%cd /kaggle/working/stable-diffusion-webui
#!git clone "https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git" extensions/tag-autocomplete
#!git clone https://github.com/d8ahazard/sd_dreambooth_extension extensions/dreambooth

# %%
#%cd /kaggle/working/stable-diffusion-webui
#!git clone https://github.com/KichangKim/DeepDanbooru

# %%
#os.listdir('/kaggle/working/stable-diffusion-webui/DeepDanbooru')
#%cd /kaggle/working/stable-diffusion-webui/DeepDanbooru
#!pip install -r requirements.txt

# %%
# %cd /kaggle/working/stable-diffusion-webui/extensions
# !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete
# !git clone https://github.com/etherealxx/batchlinks-webui
#!git clone https://github.com/Mikubill/sd-webui-controlnet
#!git clone https://github.com/hnmr293/posex
# !git clone https://github.com/KohakuBlueleaf/LyCORIS
# !git clone https://github.com/Penismusic12/a1111-sd-webui-lycoris
#!git clone https://github.com/jexom/sd-webui-depth-lib
#!git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-nsfw-censor /kaggle/working/stable-diffusion-webui/extensions/stable-diffusion-webui-nsfw-censor #kaggle
#!git clone https://github.com/jovijovi/stable-diffusion-webui-nsfw-filter /kaggle/working/stable-diffusion-webui/extensions/stable-diffusion-webui-nsfw-filter
# !aria2c -d /kaggle/working/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_openpose-fp16.safetensors https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors
# !aria2c -d /kaggle/working/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_scribble-fp16.safetensors https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_scribble-fp16.safetensors
# !aria2c -d /kaggle/working/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_depth-fp16.safetensors https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_depth-fp16.safetensors

# %%
# !aria2c -d /kaggle/working/stable-diffusion-webui/scripts -o lora_block_weight.py https://raw.githubusercontent.com/hako-mikan/sd-webui-lora-block-weight/main/scripts/lora_block_weight.py

# %%
# !aria2c -d /kaggle/working/stable-diffusion-webui -o config.json https://huggingface.co/feelinrealcute/sd-webui-defaultsettingsarchive/resolve/main/config.json
# !aria2c -d /kaggle/working/stable-diffusion-webui -o ui-config.json https://huggingface.co/feelinrealcute/sd-webui-defaultsettingsarchive/resolve/main/ui-config.json
#!cp -r /kaggle/input/sd-webui-defaultsettings/config.json /kaggle/working/stable-diffusion-webui/config.json
#!cp -r /kaggle/input/sd-webui-defaultsettings/ui-config.json /kaggle/working/stable-diffusion-webui/ui-config.json
#!cp -r /kaggle/input/stylefile/styles.csv /kaggle/working/stable-diffusion-webui/styles.csv

# %%
# %cd /kaggle/working/stable-diffusion-webui

# hacks to load model in kaggle
# !sed -i -e 's/numpy==1.23.3/numpy==1.21.6/g' requirements_versions.txt
# !sed -i -e 's/blendmodes==2022/blendmodes==2021/g' requirements_versions.txt
# !sed -i -e 's/fastapi==0.90.1/fastapi==0.89.1/g' requirements_versions.txt
# !sed -i -e 's/gradio==3.31.0/gradio==3.29.0/g' requirements_versions.txt
# !sed -i -e 's/gradio==3.31.0/gradio==3.29.0/g' requirements.txt
# !sed -i '1s/^/import os\n/' /kaggle/working/stable-diffusion-webui/launch.py
# !sed -i -e '''/    prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /kaggle/working/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /kaggle/working/stable-diffusion-webui/launch.py
# !sed -i 's/map_location=None/map_location="cuda:0"/g' /kaggle/working/stable-diffusion-webui/modules/sd_models.py
# !sed -i 's/max_models = shared.opts.data.get("control_net_max_models_num", 1)/max_models = shared.opts.data.get("control_net_max_models_num", 3)/g' /kaggle/working/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py
#!sed -i '18s/\\\\(/\\(/g' /kaggle/working/stable-diffusion-webui/modules/generation_parameters_copypaste.py
#!sed -i '302s/\*ui.pages_contents/ui.pages_contents\[0\], ui.pages_contents\[1\], ui.pages_contents\[2\]/g' /kaggle/working/stable-diffusion-webui/modules/ui_extra_networks.py

# %%
# !npm install -g localtunnel
import subprocess
import threading
import time
import socket
def iframe_thread(port):
    while True:
        time.sleep(0.5)
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        result = sock.connect_ex(('127.0.0.1', port))
        if result == 0:
            break
        sock.close()
    p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
    for line in p.stdout:
        print(line.decode(), end='')
threading.Thread(target=iframe_thread, daemon=True, args=(7860,)).start()

# %%
try:
    import os
    os_imported = True
except ImportError:
    os_imported = False

if os_imported:
    print("os module imported successfully!")
else:
    print("Failed to import os module")
#  use normal stable-diffusion
# !curl ipv4.icanhazip.com
# !wget -q -O - ipv4.icanhazip.com
# !COMMANDLINE_ARGS="--share --gradio-debug --config config.yaml --disable-safe-unpickle --gradio-auth balls:balls,undefeatable:sonic,vk9CXmGLUz:vk9CXmGLUz --xformers --gradio-queue --theme dark" REQS_FILE="requirements.txt" python launch.py

# %% [markdown]
# # ******negative prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, bad feet**
