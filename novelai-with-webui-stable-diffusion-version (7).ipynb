# %% [markdown]
# # #This Notebook is for NovelAI with Stable-Diffusion version and 7G animefull-final-latest model used.

# %%
#Test GPU 测试GPU
# !nvidia-smi

#Download SD-WebUi 下载SD-WebUi
# %cd /kaggle/working/
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
    
#Make folder for models  新建模型目录
# !mkdir -p /kaggle/working/stable-diffusion-webui/models/Stable-diffusion /kaggle/working/stable-diffusion-webui/models/hypernetworks 
# %cd /kaggle/working/stable-diffusion-webui/models/Stable-diffusion
# Out:
# Mon Nov 28 19:48:24 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.82.01    Driver Version: 470.82.01    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# /kaggle/working
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 11505, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 11505 (delta 34), reused 45 (delta 25), pack-reused 11438
# Receiving objects: 100% (11505/11505), 23.93 MiB | 9.81 MiB/s, done.
# Resolving deltas: 100% (8035/8035), done.
# /kaggle/working/stable-diffusion-webui/models/Stable-diffusion

# %%
#Select the model you like根据喜好选择模型
#Remove the # signal before the code if you want to run the model, and add the # symbol before the other
#在你想要使用的模型对应的代码前去掉#，其他模型的对应代码前加上#

#Model 1 (default) ： 7g animefull-final-latest
# 二次元和写实风兼有
#!cp -r /kaggle/input/animefulllatestckpt/animefull-latest.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest.ckpt

#Model 2: 4g animefull-final-pruned
# 二次元风格
#!cp -r /kaggle/input/nai-pruned/animefull-final-pruned.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.ckpt

#Model 3: 7g stable-diffusion-1.5
#写实风
#!cp -r /kaggle/input/stable-diffusion-1-5/v1-5-pruned.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/sd15-pruned.ckpt

#Model 4:7g Anything-v3.0
#Novel AI最新模型
#!cp -r /kaggle/input/anythingv3/Anything-V3.0.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.ckpt
#!cp -r /kaggle/input/anythingv3/Anything-V3.0.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.vae.pt

#Model 5:stable diffusion 1.5 inpainting
#专用于inpaint的模型
#!cp -r /kaggle/input/inpainting/sd-v1-5-inpainting.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt

#Model 5:7g momoko-Anything-v3.0
#看标题像momoko，哪位大哥测试一下效果？
# !cp -r /kaggle/input/momoko/momoko-any3.0.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko-any3.0.ckpt
# !cp -r /kaggle/input/momoko/momoko-any3.0.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko-any3.0.vae.pt

# %%
# !apt install -y aria2
# Models
# 7G animefull-final-latest (optional)
# !aria2c -d /kaggle/working/stable-diffusion-webui https://cloudflare-ipfs.com/ipfs/bafybeiav3j7npiuewbel3mi32l3sidgkw54kuleosbhxmdvddbnvtfi7yu/config.yaml
#!aria2c https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/animefull-latest.ckpt

# Install embeddings (optional)
# !aria2c https://cloudflare-ipfs.com/ipfs/bafybeie3hdjchxs5tz4n75bos53nhcklslguxchdurc2ynrzcfv2kwyklu/embeddings.tar
# !tar xvf embeddings.tar -C /kaggle/working/stable-diffusion-webui/embeddings && rm -rf embeddings.tar

# Install VAE Weights (optional)
# !aria2c -o animefull-final-pruned.vae.pt https://cloudflare-ipfs.com/ipfs/bafybeiccldswdd3wvg57jhclcq53lvsc6gizasiblwayvhlv6eq4wow7wu/animevae.pt 
# !ln -s animefull-final-pruned.vae.pt animefull-final-latest.vae.pt

# Install hypernetwork （optional)
# !aria2c https://cloudflare-ipfs.com/ipfs/bafybeiduanx2b3mcvxlwr66igcwnpfmk3nc3qgxlpwh6oq6m6pxii3f77e/_modules.tar  
# !tar xvf _modules.tar -C /kaggle/working/stable-diffusion-webui/models/hypernetworks && rm -rf _modules.tar
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libaria2-0 libc-ares2 libssh2-1
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2 libssh2-1
# 0 upgraded, 4 newly installed, 0 to remove and 93 not upgraded.
# Need to get 1552 kB of archives.
# After this operation, 6234 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libc-ares2 amd64 1.15.0-1ubuntu0.1 [38.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libssh2-1 amd64 1.8.0-2.1build1 [75.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 libaria2-0 amd64 1.35.0-1build1 [1082 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 aria2 amd64 1.35.0-1build1 [356 kB]
# Fetched 1552 kB in 3s (599 kB/s)0m
#
# 78Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 108827 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.15.0-1ubuntu0.1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  6%] [###.......................................................] 8Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.1) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libssh2-1:amd64.
# Preparing to unpack .../libssh2-1_1.8.0-2.1build1_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libssh2-1:amd64 (1.8.0-2.1build1) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.35.0-1build1_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libaria2-0:amd64 (1.35.0-1build1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.35.0-1build1_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking aria2 (1.35.0-1build1) ...
# 7Progress: [ 47%] [###########################...............................] 8Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.1) ...
# 7Progress: [ 53%] [##############################............................] 87Progress: [ 59%] [##################################........................] 8Setting up libssh2-1:amd64 (1.8.0-2.1build1) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 71%] [########################################..................] 8Setting up libaria2-0:amd64 (1.35.0-1build1) ...
# 7Progress: [ 76%] [############################################..............] 87Progress: [ 82%] [###############################################...........] 8Setting up aria2 (1.35.0-1build1) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 94%] [######################################################....] 8Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.7) ...
#
# 78
# 11/28 19:49:58 [NOTICE] Downloading 1 item(s)
# [#3d0c56 0B/0B CN:1 DL:0B]
# 11/28 19:49:59 [NOTICE] Download complete: /kaggle/working/stable-diffusion-webui/config.yaml
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3d0c56|OK  |   457KiB/s|/kaggle/working/stable-diffusion-webui/config.yaml
#
# Status Legend:
# (OK):download completed.
#
# 11/28 19:50:01 [NOTICE] Downloading 1 item(s)
#  *** Download Progress Summary as of Mon Nov 28 19:51:01 2022 ***              m42s]m
# ===============================================================================
# [#3774b2 29MiB/0.9GiB(2%) CN:1 DL:705KiB ETA:23m35s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 19:52:01 2022 ***              m11s]
# ===============================================================================
# [#3774b2 80MiB/0.9GiB(8%) CN:1 DL:915KiB ETA:17m13s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 19:53:02 2022 ***              37m47s]
# ===============================================================================
# [#3774b2 117MiB/0.9GiB(11%) CN:1 DL:411KiB ETA:36m50s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 19:54:03 2022 ***              16m12s]
# ===============================================================================
# [#3774b2 157MiB/0.9GiB(15%) CN:1 DL:0.9MiB ETA:15m12s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 19:55:04 2022 ***              14m31s]
# ===============================================================================
# [#3774b2 212MiB/0.9GiB(21%) CN:1 DL:1.0MiB ETA:12m47s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 19:56:04 2022 ***              7m50s]m
# ===============================================================================
# [#3774b2 293MiB/0.9GiB(29%) CN:1 DL:1.5MiB ETA:7m33s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 19:57:05 2022 ***              10m57s]
# ===============================================================================
# [#3774b2 375MiB/0.9GiB(37%) CN:1 DL:1.0MiB ETA:9m46s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 19:58:05 2022 ***              5m32s]m
# ===============================================================================
# [#3774b2 444MiB/0.9GiB(44%) CN:1 DL:1.9MiB ETA:4m44s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 19:59:05 2022 ***              21m33s]
# ===============================================================================
# [#3774b2 487MiB/0.9GiB(48%) CN:1 DL:442KiB ETA:19m55s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:00:06 2022 ***              14m54s]
# ===============================================================================
# [#3774b2 515MiB/0.9GiB(51%) CN:1 DL:524KiB ETA:15m54s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:01:07 2022 ***              10m54s]
# ===============================================================================
# [#3774b2 548MiB/0.9GiB(54%) CN:1 DL:787KiB ETA:9m52s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:02:07 2022 ***              11m29s]
# ===============================================================================
# [#3774b2 593MiB/0.9GiB(59%) CN:1 DL:645KiB ETA:10m52s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:03:08 2022 ***              5m10s]m
# ===============================================================================
# [#3774b2 680MiB/0.9GiB(67%) CN:1 DL:0.9MiB ETA:5m40s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:04:08 2022 ***              8m6s]m
# ===============================================================================
# [#3774b2 749MiB/0.9GiB(74%) CN:1 DL:522KiB ETA:8m19s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:05:09 2022 ***              3m31s]m
# ===============================================================================
# [#3774b2 799MiB/0.9GiB(79%) CN:1 DL:0.9MiB ETA:3m31s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:06:10 2022 ***              1m32s]
# ===============================================================================
# [#3774b2 880MiB/0.9GiB(87%) CN:1 DL:1.2MiB ETA:1m35s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:07:11 2022 ***              1m56s]
# ===============================================================================
# [#3774b2 0.9GiB/0.9GiB(92%) CN:1 DL:642KiB ETA:1m58s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:08:11 2022 ***              1m18s]
# ===============================================================================
# [#3774b2 0.9GiB/0.9GiB(95%) CN:1 DL:511KiB ETA:1m21s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
# -------------------------------------------------------------------------------
#
# [#3774b2 0.9GiB/0.9GiB(99%) CN:1 DL:2.9MiB]0m]mmm
# 11/28 20:08:31 [NOTICE] Download complete: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3774b2|OK  |   0.9MiB/s|/kaggle/working/stable-diffusion-webui/models/Stable-diffusion/embeddings.tar
#
# Status Legend:
# (OK):download completed.
# aini.pt
# anime.pt
# anime_2.pt
# anime_3.pt
# furry.pt
# furry_2.pt
# furry_3.pt
# furry_kemono.pt
# furry_protogen.pt
# furry_scalie.pt
# furry_transformation.pt
# pony.pt
#
# 11/28 20:08:34 [NOTICE] Downloading 1 item(s)
#  *** Download Progress Summary as of Mon Nov 28 20:09:35 2022 ***              m21s]m
# ===============================================================================
# [#52e347 53MiB/784MiB(6%) CN:1 DL:1.0MiB ETA:11m51s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:10:35 2022 ***              9m25s]m
# ===============================================================================
# [#52e347 111MiB/784MiB(14%) CN:1 DL:1.2MiB ETA:9m]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:11:36 2022 ***              5m20s]
# ===============================================================================
# [#52e347 240MiB/784MiB(30%) CN:1 DL:1.4MiB ETA:6m19s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:12:36 2022 ***              6m23s]m
# ===============================================================================
# [#52e347 296MiB/784MiB(37%) CN:1 DL:1.3MiB ETA:6m]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:13:37 2022 ***              3m12s]m
# ===============================================================================
# [#52e347 406MiB/784MiB(51%) CN:1 DL:1.8MiB ETA:3m25s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:14:37 2022 ***              1m17s]
# ===============================================================================
# [#52e347 558MiB/784MiB(71%) CN:1 DL:2.4MiB ETA:1m31s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:15:38 2022 ***              5s]m0m
# ===============================================================================
# [#52e347 768MiB/784MiB(97%) CN:1 DL:3.0MiB ETA:5s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt
# -------------------------------------------------------------------------------
#
# [#52e347 783MiB/784MiB(99%) CN:1 DL:1.2MiB ETA:1s]
# 11/28 20:15:50 [NOTICE] Download complete: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 52e347|OK  |   1.8MiB/s|/kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt
#
# Status Legend:
# (OK):download completed.
#
# 11/28 20:15:52 [NOTICE] Downloading 1 item(s)
#  *** Download Progress Summary as of Mon Nov 28 20:16:52 2022 ***              13m34s]
# ===============================================================================
# [#a25607 119MiB/0.9GiB(11%) CN:1 DL:1.0MiB ETA:13m56s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/_modules.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:17:53 2022 ***              3m55s]m
# ===============================================================================
# [#a25607 267MiB/0.9GiB(26%) CN:1 DL:2.5MiB ETA:4m46s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/_modules.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Mon Nov 28 20:18:54 2022 ***              58s]mm
# ===============================================================================
# [#a25607 635MiB/0.9GiB(63%) CN:1 DL:5.9MiB ETA:1m2s]
# FILE: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/_modules.tar
# -------------------------------------------------------------------------------
#
# [#a25607 0.9GiB/0.9GiB(99%) CN:1 DL:5.0MiB]0m]m0m
# 11/28 20:19:49 [NOTICE] Download complete: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/_modules.tar
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a25607|OK  |   4.2MiB/s|/kaggle/working/stable-diffusion-webui/models/Stable-diffusion/_modules.tar
#
# Status Legend:
# (OK):download completed.
# aini.pt
# anime.pt
# anime_2.pt
# anime_3.pt
# furry.pt
# furry_2.pt
# furry_3.pt
# furry_kemono.pt
# furry_protogen.pt
# furry_scalie.pt
# furry_transformation.pt
# pony.pt

# %%
#复制训练好的模型copy the pt file to embeddings
import os,shutil
try:
    ptlist = os.listdir('/kaggle/input/trainedpt2/')
    print(ptlist)
    for i in ptlist:
        shutil.copy('/kaggle/input/trainedpt2/'+i,'/kaggle/working/stable-diffusion-webui/embeddings/'+i)
except:
    pass

#训练备用：
#新建用于存放预处理图片的文件夹 create a folder to save the preprocessed data
# !mkdir -p /kaggle/working/preprocessed

# %%
#%cd /kaggle/working/stable-diffusion-webui
#!git clone "https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git" extensions/tag-autocomplete
#!git clone https://github.com/d8ahazard/sd_dreambooth_extension extensions/dreambooth

# %%
#%cd /kaggle/working/stable-diffusion-webui
#!git clone https://github.com/KichangKim/DeepDanbooru

# %%
#os.listdir('/kaggle/working/stable-diffusion-webui/DeepDanbooru')
#%cd /kaggle/working/stable-diffusion-webui/DeepDanbooru
#!pip install -r requirements.txt

# %%
# %cd /kaggle/working/stable-diffusion-webui/extensions
# !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete
# Out:
# /kaggle/working/stable-diffusion-webui/extensions
# Cloning into 'a1111-sd-webui-tagcomplete'...
# remote: Enumerating objects: 531, done.
# remote: Counting objects: 100% (259/259), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 531 (delta 182), reused 139 (delta 123), pack-reused 272
# Receiving objects: 100% (531/531), 3.70 MiB | 3.39 MiB/s, done.
# Resolving deltas: 100% (251/251), done.

# %%
# !cp -r /kaggle/input/sddefaultsetting/config.json /kaggle/working/stable-diffusion-webui/config.json
# !cp -r /kaggle/input/sddefaultsetting/ui-config.json /kaggle/working/stable-diffusion-webui/ui-config.json
#!cp -r /kaggle/input/stylefile/styles.csv /kaggle/working/stable-diffusion-webui/styles.csv

# %%
# %cd /kaggle/working/stable-diffusion-webui

# hacks to load model in kaggle
# !sed -i 's/map_location="cpu"/map_location="cuda"/g' /kaggle/working/stable-diffusion-webui/modules/sd_models.py

#  use normal stable-diffusion
# !COMMANDLINE_ARGS="--share --gradio-debug --config config.yaml --disable-safe-unpickle --gradio-auth balls:balls " REQS_FILE="requirements.txt" python launch.py
# Out:
# /kaggle/working/stable-diffusion-webui
# Python 3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53)
# [GCC 9.4.0]
# Commit hash: 0b5dcb3d7ce397ad38312dbfc70febe7bb42dcc3
# Installing gfpgan
# Installing clip
# Installing open_clip
# Cloning Stable Diffusion into repositories/stable-diffusion-stability-ai...
# Cloning Taming Transformers into repositories/taming-transformers...
# Cloning K-diffusion into repositories/k-diffusion...
# Cloning CodeFormer into repositories/CodeFormer...
# Cloning BLIP into repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements for Web UI
# Launching Web UI with arguments: --share --gradio-debug --config config.yaml --disable-safe-unpickle --gradio-auth balls:balls
# No module 'xformers'. Proceeding without it.
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Downloading: 100%|████████████████████████████| 939k/939k [00:01<00:00, 872kB/s]
# Downloading: 100%|████████████████████████████| 512k/512k [00:00<00:00, 708kB/s]
# Downloading: 100%|██████████████████████████████| 389/389 [00:00<00:00, 234kB/s]
# Downloading: 100%|██████████████████████████████| 905/905 [00:00<00:00, 718kB/s]
# Downloading: 100%|█████████████████████████| 4.41k/4.41k [00:00<00:00, 3.26MB/s]
# Downloading: 100%|█████████████████████████| 1.59G/1.59G [02:22<00:00, 12.0MB/s]
# Loading weights [4e7fc52f] from /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko-any3.0.ckpt
# Using VAE found similar to selected model: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko-any3.0.vae.pt
# Loading VAE weights from: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko-any3.0.vae.pt
# Applying cross attention optimization (Doggettx).
# Model loaded.
# Loaded a total of 12 textual inversion embeddings.
# Embeddings: furry_2, anime_2, furry_scalie, aini, pony, furry_3, anime, furry_kemono, furry_protogen, furry, furry_transformation, anime_3
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://3b67395d149f775b.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
#   0%|                                                    | 0/28 [00:00<?, ?it/s]
#   4%|█▌                                          | 1/28 [00:05<02:25,  5.38s/it]
#   7%|███▏                                        | 2/28 [00:05<01:07,  2.58s/it]
#  11%|████▋                                       | 3/28 [00:06<00:42,  1.68s/it]
#  14%|██████▎                                     | 4/28 [00:07<00:30,  1.26s/it]
#  18%|███████▊                                    | 5/28 [00:07<00:23,  1.03s/it]
#  21%|█████████▍                                  | 6/28 [00:08<00:19,  1.12it/s]
#  25%|███████████                                 | 7/28 [00:09<00:16,  1.24it/s]
#  29%|████████████▌                               | 8/28 [00:09<00:14,  1.34it/s]
#  32%|██████████████▏                             | 9/28 [00:10<00:13,  1.42it/s]
#  36%|███████████████▎                           | 10/28 [00:10<00:12,  1.47it/s]
#  39%|████████████████▉                          | 11/28 [00:11<00:11,  1.51it/s]
#  43%|██████████████████▍                        | 12/28 [00:12<00:10,  1.54it/s]
#  46%|███████████████████▉                       | 13/28 [00:12<00:09,  1.56it/s]
#  50%|█████████████████████▌                     | 14/28 [00:13<00:08,  1.58it/s]
#  54%|███████████████████████                    | 15/28 [00:14<00:08,  1.59it/s]
#  57%|████████████████████████▌                  | 16/28 [00:14<00:07,  1.60it/s]
#  61%|██████████████████████████                 | 17/28 [00:15<00:06,  1.60it/s]
#  64%|███████████████████████████▋               | 18/28 [00:15<00:06,  1.60it/s]
#  68%|█████████████████████████████▏             | 19/28 [00:16<00:05,  1.61it/s]
#  71%|██████████████████████████████▋            | 20/28 [00:17<00:04,  1.61it/s]
#  75%|████████████████████████████████▎          | 21/28 [00:17<00:04,  1.61it/s]
#  79%|█████████████████████████████████▊         | 22/28 [00:18<00:03,  1.61it/s]
#  82%|███████████████████████████████████▎       | 23/28 [00:19<00:03,  1.61it/s]
#  86%|████████████████████████████████████▊      | 24/28 [00:19<00:02,  1.61it/s]
#  89%|██████████████████████████████████████▍    | 25/28 [00:20<00:01,  1.61it/s]
#  93%|███████████████████████████████████████▉   | 26/28 [00:20<00:01,  1.61it/s]
#  96%|█████████████████████████████████████████▍ | 27/28 [00:21<00:00,  1.61it/s]
# 100%|███████████████████████████████████████████| 28/28 [00:22<00:00,  1.27it/s]
# Total progress: 100%|███████████████████████████| 28/28 [00:18<00:00,  1.55it/s]
#   0%|                                                    | 0/28 [00:00<?, ?it/s]
#   4%|█▌                                          | 1/28 [00:00<00:07,  3.61it/s]
#   7%|███▏                                        | 2/28 [00:00<00:12,  2.09it/s]
#  11%|████▋                                       | 3/28 [00:01<00:13,  1.84it/s]
#  14%|██████▎                                     | 4/28 [00:02<00:13,  1.74it/s]
#  18%|███████▊                                    | 5/28 [00:02<00:13,  1.69it/s]
#  21%|█████████▍                                  | 6/28 [00:03<00:13,  1.67it/s]
#  25%|███████████                                 | 7/28 [00:03<00:12,  1.65it/s]
#  29%|████████████▌                               | 8/28 [00:04<00:12,  1.64it/s]
#  32%|██████████████▏                             | 9/28 [00:05<00:11,  1.63it/s]
#  36%|███████████████▎                           | 10/28 [00:05<00:11,  1.62it/s]
#  39%|████████████████▉                          | 11/28 [00:06<00:10,  1.62it/s]
#  43%|██████████████████▍                        | 12/28 [00:07<00:09,  1.62it/s]
#  46%|███████████████████▉                       | 13/28 [00:07<00:09,  1.62it/s]
#  50%|█████████████████████▌                     | 14/28 [00:08<00:08,  1.62it/s]
#  54%|███████████████████████                    | 15/28 [00:08<00:08,  1.61it/s]
#  57%|████████████████████████▌                  | 16/28 [00:09<00:07,  1.61it/s]
#  61%|██████████████████████████                 | 17/28 [00:10<00:06,  1.61it/s]
#  64%|███████████████████████████▋               | 18/28 [00:10<00:06,  1.61it/s]
#  68%|█████████████████████████████▏             | 19/28 [00:11<00:05,  1.61it/s]
#  71%|██████████████████████████████▋            | 20/28 [00:12<00:04,  1.61it/s]
#  75%|████████████████████████████████▎          | 21/28 [00:12<00:04,  1.61it/s]
#  79%|█████████████████████████████████▊         | 22/28 [00:13<00:03,  1.61it/s]
#  82%|███████████████████████████████████▎       | 23/28 [00:13<00:03,  1.61it/s]
#  86%|████████████████████████████████████▊      | 24/28 [00:14<00:02,  1.61it/s]
#  89%|██████████████████████████████████████▍    | 25/28 [00:15<00:01,  1.61it/s]
#  93%|███████████████████████████████████████▉   | 26/28 [00:15<00:01,  1.61it/s]
#  96%|█████████████████████████████████████████▍ | 27/28 [00:16<00:00,  1.61it/s]
# 100%|███████████████████████████████████████████| 28/28 [00:17<00:00,  1.64it/s]
# Total progress: 100%|███████████████████████████| 28/28 [00:18<00:00,  1.55it/s]
# Using VAE found similar to selected model: /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko-any3.0.vae.pt
# Loading hypernetwork anime(1145414c)
# [1, 2, 1]
# Activation function is None
# Weight initialization is Normal
# Layer norm is set to False
# Dropout usage is set to False
# Activate last layer is set to True
# Optimizer name is AdamW
# No saved optimizer exists in checkpoint
#   0%|                                                    | 0/28 [00:00<?, ?it/s]
#   4%|█▌                                          | 1/28 [00:00<00:09,  2.93it/s]
#   7%|███▏                                        | 2/28 [00:01<00:14,  1.84it/s]
#  11%|████▋                                       | 3/28 [00:01<00:15,  1.65it/s]
#  14%|██████▎                                     | 4/28 [00:02<00:15,  1.57it/s]
#  18%|███████▊                                    | 5/28 [00:03<00:15,  1.53it/s]
#  21%|█████████▍                                  | 6/28 [00:03<00:14,  1.51it/s]
#  25%|███████████                                 | 7/28 [00:04<00:14,  1.49it/s]
#  29%|████████████▌                               | 8/28 [00:05<00:13,  1.48it/s]
#  32%|██████████████▏                             | 9/28 [00:05<00:12,  1.48it/s]
#  36%|███████████████▎                           | 10/28 [00:06<00:12,  1.47it/s]
#  39%|████████████████▉                          | 11/28 [00:07<00:11,  1.47it/s]
#  43%|██████████████████▍                        | 12/28 [00:07<00:10,  1.47it/s]
#  46%|███████████████████▉                       | 13/28 [00:08<00:10,  1.47it/s]
#  50%|█████████████████████▌                     | 14/28 [00:09<00:09,  1.47it/s]
#  54%|███████████████████████                    | 15/28 [00:09<00:08,  1.47it/s]
#  57%|████████████████████████▌                  | 16/28 [00:10<00:08,  1.47it/s]
#  61%|██████████████████████████                 | 17/28 [00:11<00:07,  1.47it/s]
#  64%|███████████████████████████▋               | 18/28 [00:11<00:06,  1.47it/s]
#  68%|█████████████████████████████▏             | 19/28 [00:12<00:06,  1.46it/s]
#  71%|██████████████████████████████▋            | 20/28 [00:13<00:05,  1.46it/s]
#  75%|████████████████████████████████▎          | 21/28 [00:14<00:04,  1.46it/s]
#  79%|█████████████████████████████████▊         | 22/28 [00:14<00:04,  1.46it/s]
#  82%|███████████████████████████████████▎       | 23/28 [00:15<00:03,  1.46it/s]
#  86%|████████████████████████████████████▊      | 24/28 [00:16<00:02,  1.46it/s]
#  89%|██████████████████████████████████████▍    | 25/28 [00:16<00:02,  1.46it/s]
#  93%|███████████████████████████████████████▉   | 26/28 [00:17<00:01,  1.46it/s]
#  96%|█████████████████████████████████████████▍ | 27/28 [00:18<00:00,  1.46it/s]
# 100%|███████████████████████████████████████████| 28/28 [00:18<00:00,  1.49it/s]
# Total progress: 100%|███████████████████████████| 28/28 [00:19<00:00,  1.42it/s]
#   0%|                                                    | 0/28 [00:00<?, ?it/s]
#   4%|█▌                                          | 1/28 [00:00<00:09,  2.89it/s]
#   7%|███▏                                        | 2/28 [00:01<00:14,  1.84it/s]
#  11%|████▋                                       | 3/28 [00:01<00:15,  1.65it/s]
#  14%|██████▎                                     | 4/28 [00:02<00:15,  1.57it/s]
#  18%|███████▊                                    | 5/28 [00:03<00:15,  1.53it/s]
#  21%|█████████▍                                  | 6/28 [00:03<00:14,  1.51it/s]
#  25%|███████████                                 | 7/28 [00:04<00:14,  1.49it/s]
#  29%|████████████▌                               | 8/28 [00:05<00:13,  1.48it/s]
#  32%|██████████████▏                             | 9/28 [00:05<00:12,  1.48it/s]
#  36%|███████████████▎                           | 10/28 [00:06<00:12,  1.47it/s]
#  39%|████████████████▉                          | 11/28 [00:07<00:11,  1.47it/s]
#  43%|██████████████████▍                        | 12/28 [00:07<00:10,  1.47it/s]
#  46%|███████████████████▉                       | 13/28 [00:08<00:10,  1.47it/s]
#  50%|█████████████████████▌                     | 14/28 [00:09<00:09,  1.47it/s]
#  54%|███████████████████████                    | 15/28 [00:09<00:08,  1.47it/s]
#  57%|████████████████████████▌                  | 16/28 [00:10<00:08,  1.47it/s]
#  61%|██████████████████████████                 | 17/28 [00:11<00:07,  1.46it/s]
#  64%|███████████████████████████▋               | 18/28 [00:11<00:06,  1.46it/s]
#  68%|█████████████████████████████▏             | 19/28 [00:12<00:06,  1.46it/s]
#  71%|██████████████████████████████▋            | 20/28 [00:13<00:05,  1.46it/s]
#  75%|████████████████████████████████▎          | 21/28 [00:13<00:04,  1.46it/s]
#  79%|█████████████████████████████████▊         | 22/28 [00:14<00:04,  1.46it/s]
#  82%|███████████████████████████████████▎       | 23/28 [00:15<00:03,  1.46it/s]
#  86%|████████████████████████████████████▊      | 24/28 [00:16<00:02,  1.46it/s]
#  89%|██████████████████████████████████████▍    | 25/28 [00:16<00:02,  1.46it/s]
#  93%|███████████████████████████████████████▉   | 26/28 [00:17<00:01,  1.46it/s]
#  96%|█████████████████████████████████████████▍ | 27/28 [00:18<00:00,  1.46it/s]
# 100%|███████████████████████████████████████████| 28/28 [00:18<00:00,  1.49it/s]
# Total progress: 100%|███████████████████████████| 28/28 [00:19<00:00,  1.42it/s]
#   0%|                                                    | 0/28 [00:00<?, ?it/s]
#   4%|█▌                                          | 1/28 [00:00<00:09,  2.93it/s]
#   7%|███▏                                        | 2/28 [00:01<00:14,  1.85it/s]
#  11%|████▋                                       | 3/28 [00:01<00:15,  1.65it/s]
#  14%|██████▎                                     | 4/28 [00:02<00:15,  1.57it/s]
#  18%|███████▊                                    | 5/28 [00:03<00:15,  1.53it/s]
#  21%|█████████▍                                  | 6/28 [00:03<00:14,  1.51it/s]
#  25%|███████████                                 | 7/28 [00:04<00:14,  1.49it/s]
#  29%|████████████▌                               | 8/28 [00:05<00:13,  1.48it/s]
#  32%|██████████████▏                             | 9/28 [00:05<00:12,  1.48it/s]
#  36%|███████████████▎                           | 10/28 [00:06<00:12,  1
/s]
#  69%|█████████████████████████████▌             | 11/16 [00:03<00:01,  2.98it/s]
#  75%|████████████████████████████████▎          | 12/16 [00:04<00:01,  2.98it/s]
#  81%|██████████████████████████████████▉        | 13/16 [00:04<00:01,  2.98it/s]
#  88%|█████████████████████████████████████▋     | 14/16 [00:04<00:00,  2.98it/s]
#  94%|████████████████████████████████████████▎  | 15/16 [00:05<00:00,  2.98it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:05<00:00,  2.98it/s]
# Total progress: 100%|███████████████████████████| 16/16 [00:05<00:00,  2.88it/s]
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
#   6%|██▊                                         | 1/16 [00:00<00:03,  4.35it/s]
#  12%|█████▌                                      | 2/16 [00:00<00:05,  2.74it/s]
#  19%|████████▎                                   | 3/16 [00:01<00:05,  2.46it/s]
#  25%|███████████                                 | 4/16 [00:01<00:05,  2.34it/s]
#  31%|█████████████▊                              | 5/16 [00:02<00:04,  2.28it/s]
#  38%|████████████████▌                           | 6/16 [00:02<00:04,  2.24it/s]
#  44%|███████████████████▎                        | 7/16 [00:02<00:04,  2.22it/s]
#  50%|██████████████████████                      | 8/16 [00:03<00:03,  2.21it/s]
#  56%|████████████████████████▊                   | 9/16 [00:03<00:03,  2.20it/s]
#  62%|██████████████████████████▉                | 10/16 [00:04<00:02,  2.20it/s]
#  69%|█████████████████████████████▌             | 11/16 [00:04<00:02,  2.19it/s]
#  75%|████████████████████████████████▎          | 12/16 [00:05<00:01,  2.19it/s]
#  81%|██████████████████████████████████▉        | 13/16 [00:05<00:01,  2.19it/s]
#  88%|█████████████████████████████████████▋     | 14/16 [00:06<00:00,  2.19it/s]
#  94%|████████████████████████████████████████▎  | 15/16 [00:06<00:00,  2.18it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:07<00:00,  2.25it/s]
# Total progress: 100%|███████████████████████████| 16/16 [00:07<00:00,  2.06it/s]
#   0%|                                                    | 0/14 [00:00<?, ?it/s]
#   7%|███▏                                        | 1/14 [00:00<00:02,  4.35it/s]
#  14%|██████▎                                     | 2/14 [00:00<00:04,  2.75it/s]
#  21%|█████████▍                                  | 3/14 [00:01<00:04,  2.46it/s]
#  29%|████████████▌                               | 4/14 [00:01<00:04,  2.34it/s]
#  36%|███████████████▋                            | 5/14 [00:02<00:03,  2.28it/s]
#  43%|██████████████████▊                         | 6/14 [00:02<00:03,  2.25it/s]
#  50%|██████████████████████                      | 7/14 [00:02<00:03,  2.23it/s]
#  57%|█████████████████████████▏                  | 8/14 [00:03<00:02,  2.21it/s]
#  64%|████████████████████████████▎               | 9/14 [00:03<00:02,  2.20it/s]
#  71%|██████████████████████████████▋            | 10/14 [00:04<00:01,  2.20it/s]
#  79%|█████████████████████████████████▊         | 11/14 [00:04<00:01,  2.19it/s]
#  86%|████████████████████████████████████▊      | 12/14 [00:05<00:00,  2.19it/s]
#  93%|███████████████████████████████████████▉   | 13/14 [00:05<00:00,  2.19it/s]
# 100%|███████████████████████████████████████████| 14/14 [00:06<00:00,  2.26it/s]
# Total progress: 100%|███████████████████████████| 14/14 [00:06<00:00,  2.05it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#   7%|██▉                                         | 1/15 [00:00<00:03,  4.33it/s]
#  13%|█████▊                                      | 2/15 [00:00<00:04,  2.74it/s]
#  20%|████████▊                                   | 3/15 [00:01<00:04,  2.45it/s]
#  27%|███████████▋                                | 4/15 [00:01<00:04,  2.34it/s]
#  33%|██████████████▋                             | 5/15 [00:02<00:04,  2.28it/s]
#  40%|█████████████████▌                          | 6/15 [00:02<00:04,  2.25it/s]
#  47%|████████████████████▌                       | 7/15 [00:02<00:03,  2.23it/s]
#  53%|███████████████████████▍                    | 8/15 [00:03<00:03,  2.21it/s]
#  60%|██████████████████████████▍                 | 9/15 [00:03<00:02,  2.20it/s]
#  67%|████████████████████████████▋              | 10/15 [00:04<00:02,  2.20it/s]
#  73%|███████████████████████████████▌           | 11/15 [00:04<00:01,  2.19it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:05<00:01,  2.19it/s]
#  87%|█████████████████████████████████████▎     | 13/15 [00:05<00:00,  2.19it/s]
#  93%|████████████████████████████████████████▏  | 14/15 [00:06<00:00,  2.19it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:06<00:00,  2.26it/s]
# Total progress: 100%|███████████████████████████| 15/15 [00:07<00:00,  2.07it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#   7%|██▉                                         | 1/15 [00:00<00:03,  4.23it/s]
#  13%|█████▊                                      | 2/15 [00:00<00:04,  2.73it/s]
#  20%|████████▊                                   | 3/15 [00:01<00:04,  2.45it/s]
#  27%|███████████▋                                | 4/15 [00:01<00:04,  2.34it/s]
#  33%|██████████████▋                             | 5/15 [00:02<00:04,  2.28it/s]
#  40%|█████████████████▌                          | 6/15 [00:02<00:04,  2.25it/s]
#  47%|████████████████████▌                       | 7/15 [00:02<00:03,  2.23it/s]
#  53%|███████████████████████▍                    | 8/15 [00:03<00:03,  2.21it/s]
#  60%|██████████████████████████▍                 | 9/15 [00:03<00:02,  2.20it/s]
#  67%|████████████████████████████▋              | 10/15 [00:04<00:02,  2.20it/s]
#  73%|███████████████████████████████▌           | 11/15 [00:04<00:01,  2.19it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:05<00:01,  2.19it/s]
#  87%|█████████████████████████████████████▎     | 13/15 [00:05<00:00,  2.19it/s]
#  93%|████████████████████████████████████████▏  | 14/15 [00:06<00:00,  2.19it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:06<00:00,  2.26it/s]
# Total progress: 100%|███████████████████████████| 15/15 [00:07<00:00,  2.06it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#   7%|██▉                                         | 1/15 [00:00<00:03,  4.32it/s]
#  13%|█████▊                                      | 2/15 [00:00<00:04,  2.75it/s]
#  20%|████████▊                                   | 3/15 [00:01<00:04,  2.46it/s]
#  27%|███████████▋                                | 4/15 [00:01<00:04,  2.34it/s]
#  33%|██████████████▋                             | 5/15 [00:02<00:04,  2.28it/s]
#  40%|█████████████████▌                          | 6/15 [00:02<00:04,  2.25it/s]
#  47%|████████████████████▌                       | 7/15 [00:02<00:03,  2.23it/s]
#  53%|███████████████████████▍                    | 8/15 [00:03<00:03,  2.21it/s]
#  60%|██████████████████████████▍                 | 9/15 [00:03<00:02,  2.20it/s]
#  67%|████████████████████████████▋              | 10/15 [00:04<00:02,  2.20it/s]
#  73%|███████████████████████████████▌           | 11/15 [00:04<00:01,  2.19it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:05<00:01,  2.19it/s]
#  87%|█████████████████████████████████████▎     | 13/15 [00:05<00:00,  2.19it/s]
#  93%|████████████████████████████████████████▏  | 14/15 [00:06<00:00,  2.19it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:06<00:00,  2.26it/s]
# Total progress: 100%|███████████████████████████| 15/15 [00:07<00:00,  2.06it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#   7%|██▉                                         | 1/15 [00:00<00:03,  4.34it/s]
#  13%|█████▊                                      | 2/15 [00:00<00:04,  2.75it/s]
#  20%|████████▊                                   | 3/15 [00:01<00:04,  2.46it/s]
#  27%|███████████▋                                | 4/15 [00:01<00:04,  2.34it/s]
#  33%|██████████████▋                             | 5/15 [00:02<00:04,  2.28it/s]
#  40%|█████████████████▌                          | 6/15 [00:02<00:04,  2.25it/s]
#  47%|████████████████████▌                       | 7/15 [00:02<00:03,  2.23it/s]
#  53%|███████████████████████▍                    | 8/15 [00:03<00:03,  2.21it/s]
#  60%|██████████████████████████▍                 | 9/15 [00:03<00:02,  2.20it/s]
#  67%|████████████████████████████▋              | 10/15 [00:04<00:02,  2.20it/s]
#  73%|███████████████████████████████▌           | 11/15 [00:04<00:01,  2.19it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:05<00:01,  2.19it/s]
#  87%|█████████████████████████████████████▎     | 13/15 [00:05<00:00,  2.19it/s]
#  93%|████████████████████████████████████████▏  | 14/15 [00:06<00:00,  2.19it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:06<00:00,  2.26it/s]
# Total progress: 100%|███████████████████████████| 15/15 [00:07<00:00,  2.06it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#   7%|██▉                                         | 1/15 [00:00<00:03,  4.34it/s]
#  13%|█████▊                                      | 2/15 [00:00<00:04,  2.74it/s]
#  20%|████████▊                                   | 3/15 [00:01<00:04,  2.46it/s]
#  27%|███████████▋                                | 4/15 [00:01<00:04,  2.34it/s]
#  33%|██████████████▋                             | 5/15 [00:02<00:04,  2.28it/s]
#  40%|█████████████████▌                          | 6/15 [00:02<00:04,  2.25it/s]
#  47%|████████████████████▌                       | 7/15 [00:02<00:03,  2.23it/s]
#  53%|███████████████████████▍                    | 8/15 [00:03<00:03,  2.21it/s]
#  60%|██████████████████████████▍                 | 9/15 [00:03<00:02,  2.20it/s]
#  67%|████████████████████████████▋              | 10/15 [00:04<00:02,  2.19it/s]
#  73%|███████████████████████████████▌           | 11/15 [00:04<00:01,  2.19it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:05<00:01,  2.19it/s]
#  87%|█████████████████████████████████████▎     | 13/15 [00:05<00:00,  2.19it/s]
#  93%|████████████████████████████████████████▏  | 14/15 [00:06<00:00,  2.19it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:06<00:00,  2.26it/s]
# Total progress: 100%|███████████████████████████| 15/15 [00:07<00:00,  2.06it/s]
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
#   6%|██▊                                         | 1/16 [00:00<00:03,  4.34it/s]
#  12%|█████▌                                      | 2/16 [00:00<00:05,  2.75it/s]
#  19%|████████▎                                   | 3/16 [00:01<00:05,  2.46it/s]
#  25%|███████████                                 | 4/16 [00:01<00:05,  2.34it/s]
#  31%|█████████████▊                              | 5/16 [00:02<00:04,  2.28it/s]
#  38%|████████████████▌                           | 6/16 [00:02<00:04,  2.25it/s]
#  44%|███████████████████▎                        | 7/16 [00:02<00:04,  2.23it/s]
#  50%|██████████████████████                      | 8/16 [00:03<00:03,  2.21it/s]
#  56%|████████████████████████▊                   | 9/16 [00:03<00:03,  2.20it/s]
#  62%|██████████████████████████▉                | 10/16 [00:04<00:02,  2.20it/s]
#  69%|█████████████████████████████▌             | 11/16 [00:04<00:02,  2.19it/s]
#  75%|████████████████████████████████▎          | 12/16 [00:05<00:01,  2.19it/s]
#  81%|██████████████████████████████████▉        | 13/16 [00:05<00:01,  2.19it/s]
#  88%|█████████████████████████████████████▋     | 14/16 [00:06<00:00,  2.19it/s]
#  94%|████████████████████████████████████████▎  | 15/16 [00:06<00:00,  2.18it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:07<00:00,  2.25it/s]
# Total progress: 100%|███████████████████████████| 16/16 [00:07<00:00,  2.07it/s]
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
#   6%|██▊                                         | 1/16 [00:00<00:03,  4.34it/s]
#  12%|█████▌                                      | 2/16 [00:00<00:05,  2.75it/s]
#  19%|████████▎                                   | 3/16 [00:01<00:05,  2.46it/s]
#  25%|███████████                                 | 4/16 [00:01<00:05,  2.34it/s]
#  31%|█████████████▊                              | 5/16 [00:02<00:04,  2.28it/s]
#  38%|████████████████▌                           | 6/16 [00:02<00:04,  2.25it/s]
#  44%|███████████████████▎                        | 7/16 [00:02<00:04,  2.23it/s]
#  50%|██████████████████████                      | 8/16 [00:03<00:03,  2.21it/s]
#  56%|████████████████████████▊                   | 9/16 [00:03<00:03,  2.20it/s]
#  62%|██████████████████████████▉                | 10/16 [00:04<00:02,  2.20it/s]
#  69%|█████████████████████████████▌             | 11/16 [00:04<00:02,  2.19it/s]
#  75%|████████████████████████████████▎          | 12/16 [00:05<00:01,  2.19it/s]
#  81%|██████████████████████████████████▉        | 13/16 [00:05<00:01,  2.19it/s]
#  88%|█████████████████████████████████████▋     | 14/16 [00:06<00:00,  2.19it/s]
#  94%|████████████████████████████████████████▎  | 15/16 [00:06<00:00,  2.19it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:07<00:00,  2.25it/s]
# Total progress: 100%|███████████████████████████| 16/16 [00:07<00:00,  2.07it/s]
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
#   6%|██▊                                         | 1/16 [00:00<00:03,  4
#  26%|███████████▌                                | 5/19 [00:02<00:06,  2.28it/s]
#  32%|█████████████▉                              | 6/19 [00:02<00:05,  2.24it/s]
#  37%|████████████████▏                           | 7/19 [00:02<00:05,  2.22it/s]
#  42%|██████████████████▌                         | 8/19 [00:03<00:04,  2.21it/s]
#  47%|████████████████████▊                       | 9/19 [00:03<00:04,  2.20it/s]
#  53%|██████████████████████▋                    | 10/19 [00:04<00:04,  2.20it/s]
#  58%|████████████████████████▉                  | 11/19 [00:04<00:03,  2.19it/s]
#  63%|███████████████████████████▏               | 12/19 [00:05<00:03,  2.19it/s]
#  68%|█████████████████████████████▍             | 13/19 [00:05<00:02,  2.19it/s]
#  74%|███████████████████████████████▋           | 14/19 [00:06<00:02,  2.19it/s]
#  79%|█████████████████████████████████▉         | 15/19 [00:06<00:01,  2.18it/s]
#  84%|████████████████████████████████████▏      | 16/19 [00:07<00:01,  2.18it/s]
#  89%|██████████████████████████████████████▍    | 17/19 [00:07<00:00,  2.18it/s]
#  95%|████████████████████████████████████████▋  | 18/19 [00:08<00:00,  2.18it/s]
# 100%|███████████████████████████████████████████| 19/19 [00:08<00:00,  2.24it/s]
# Total progress: 100%|███████████████████████████| 19/19 [00:09<00:00,  2.09it/s]
# ^C
# Interrupted with signal 2 in <frame at 0x7efe606737d0, file '/opt/conda/lib/python3.7/site-packages/gradio/blocks.py', line 1559, code block_thread>

# %% [markdown]
# # ******negative prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, bad feet**

# %%
# Pack images to output.zip. You can then download it at "Data-Output" area. 将图片打包复制出来，便于保存
# !zip -q -r output1.zip /kaggle/working/stable-diffusion-webui/outputs 
# !mv /kaggle/working/stable-diffusion-webui/output1.zip /kaggle/working/output1.zip
# Out:
# zip error: Nothing to do! (try: zip -q -r output1.zip . -i /kaggle/working/stable-diffusion-webui/outputs)
# mv: cannot stat '/kaggle/working/stable-diffusion-webui/output1.zip': No such file or directory

# %% [markdown]
# * # The following codes are for training 以下代码训练时用

# %%
#训练前修改vae文件
# !mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest1.vae.pt 
# !mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned1.vae.pt
# !mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.01.vae.pt
# !mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko/momoko-any3.0.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko/momoko-any3.01.vae.pt

# %%
#训练后改回vae文件
# !mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest1.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest.vae.pt 
# !mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned1.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt
# !mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.01.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.vae.pt
# !mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko/momoko-any3.01.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko/momoko-any3.0.vae.pt

# %%
#copy the pt file for saving 将训练好的模型复制出来，便于保存
# !cp -r /kaggle/working/stable-diffusion-webui/embeddings/ZYX13.pt /kaggle/working/ZYX13.pt    #修改pt文件名

# %%
os.listdir('/kaggle/working/stable-diffusion-webui/extensions/tagcomplete-3w2-cn')
#!cp -r /kaggle/working/stable-diffusion-webui/ui-config.json /kaggle/working/ui-config.json
#!cp -r /kaggle/working/stable-diffusion-webui/config.json /kaggle/working/config.json
# !cp -r /kaggle/working/stable-diffusion-webui/styles.csv /kaggle/working/styles.csv
